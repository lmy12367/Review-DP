# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %%
##生成数据集

def synthetic_data(w,b,num_examples):
    X=torch.normal(0,1,(num_examples,len(w)))
    y=torch.torch.matmul(X,w) + b
    y += torch.normal(0,0.0,y.shape)
    return X,y.reshape((-1,1))

# %%
true_w = torch.tensor([2,-3.4])
true_b = 4.2
features,labels = synthetic_data(true_w,true_b,1000)

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: tensor([1.1404, 0.4490])
# label: tensor([4.9540])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %%
##读取数据集

# %%
def data_iter(batch_size,features,labels):
    num_examples=len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices=torch.tensor(
            indices[i:min(i + batch_size,num_examples)]
        )
        yield features[batch_indices],labels[batch_indices]

# %%
batch_size =10
for X,y in data_iter(batch_size,features,labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[-0.7406, -0.6150],
#         [ 0.4597,  0.8632],
#         [-1.2002, -0.5569],
#         [-0.1547, -0.1203],
#         [-0.5409, -0.6873],
#         [ 0.5779,  0.7590],
#         [-0.5774, -1.4411],
#         [ 1.1470,  1.6257],
#         [-1.6207, -1.3920],
#         [-0.6921, -0.7816]])
#  tensor([[4.8098],
#         [2.1844],
#         [3.6933],
#         [4.2997],
#         [5.4551],
#         [2.7753],
#         [7.9448],
#         [0.9668],
#         [5.6913],
#         [5.4734]])

# %%
w=torch.normal(0,0.01,size=(2,1),requires_grad=True)
b=torch.zeros(1,requires_grad=True)

# %%
def linreg(X,w,b):
    return torch.matmul(X,w)+b

# %%
def squared_loss(y_hat,y):
    return (y_hat - y.reshape(y_hat.shape))**2/2

# %%
def sgd(params,lr ,batch_size):
    with torch.no_grad():
        for param in params:
            param  -= lr * param.grad/batch_size
            param.grad.zero_()

# %%
lr = 0.03
num_epochs=3
net = linreg
loss = squared_loss

# %%
for epoch in range(num_epochs):
    for X,y in data_iter(batch_size,features,labels):
        l=loss(net(X,w,b),y)
        l.sum().backward()
        sgd([w,b],lr,batch_size)
        with torch.no_grad():
            train_l=loss(net(features,w,b),labels)
            print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 14.939878
# epoch 1, loss 14.252943
# epoch 1, loss 12.966008
# epoch 1, loss 11.884527
# epoch 1, loss 11.272540
# epoch 1, loss 10.236834
# epoch 1, loss 9.333899
# epoch 1, loss 8.933037
# epoch 1, loss 7.991685
# epoch 1, loss 7.521202
# epoch 1, loss 7.248110
# epoch 1, loss 6.983729
# epoch 1, loss 6.143193
# epoch 1, loss 5.948604
# epoch 1, loss 5.655476
# epoch 1, loss 5.500741
# epoch 1, loss 4.966597
# epoch 1, loss 4.763946
# epoch 1, loss 4.471159
# epoch 1, loss 4.192977
# epoch 1, loss 4.025247
# epoch 1, loss 3.733894
# epoch 1, loss 3.390333
# epoch 1, loss 3.166748
# epoch 1, loss 3.018513
# epoch 1, loss 2.896207
# epoch 1, loss 2.683322
# epoch 1, loss 2.365588
# epoch 1, loss 2.219639
# epoch 1, loss 2.134558
# epoch 1, loss 2.011149
# epoch 1, loss 1.878877
# epoch 1, loss 1.832416
# epoch 1, loss 1.752661
# epoch 1, loss 1.603728
# epoch 1, loss 1.537206
# epoch 1, loss 1.458044
# epoch 1, loss 1.324563
# epoch 1, loss 1.303770
# epoch 1, loss 1.201382
# epoch 1, loss 1.154140
# epoch 1, loss 1.110852
# epoch 2, loss 0.000851
# epoch 2, loss 0.000797
# epoch 2, loss 0.000768
# epoch 2, loss 0.000716
# epoch 2, loss 0.000669
# epoch 2, loss 0.000643
# epoch 2, loss 0.000615
# epoch 2, loss 0.000579
# epoch 2, loss 0.000532
# epoch 2, loss 0.000516
# epoch 2, loss 0.000498
# epoch 2, loss 0.000449
# epoch 2, loss 0.000434
# epoch 2, loss 0.000399
# epoch 2, loss 0.000364
# epoch 2, loss 0.000330
# epoch 2, loss 0.000315
# epoch 2, loss 0.000305
# epoch 2, loss 0.000292
# epoch 2, loss 0.000271
# epoch 2, loss 0.000239
# epoch 2, loss 0.000231
# epoch 2, loss 0.000209
# epoch 2, loss 0.000190
# epoch 2, loss 0.000177
# epoch 2, loss 0.000156
# epoch 2, loss 0.000148
# epoch 2, loss 0.000142
# epoch 2, loss 0.000130
# epoch 2, loss 0.000122
# epoch 2, loss 0.000113
# epoch 2, loss 0.000103
# epoch 2, loss 0.000099
# epoch 2, loss 0.000095
# epoch 2, loss 0.000089
# epoch 2, loss 0.000083
# epoch 2, loss 0.000080
# epoch 2, loss 0.000076
# epoch 2, loss 0.000071
# epoch 2, loss 0.000069
# epoch 2, loss 0.000065
# epoch 2, loss 0.000064
# epoch 3, loss 0.000060
# epoch 3, loss 0.000057
# epoch 3, loss 0.000051
# epoch 3, loss 0.000047
# epoch 3, loss 0.000045
# epoch 3, loss 0.000042
# epoch 3, loss 0.000038
# epoch 3, loss 0.000037
# epoch 3, loss 0.000036
# epoch 3, loss 0.000034
# epoch 3, loss 0.000032
# epoch 3, loss 0.000030
# epoch 3, loss 0.000029
# epoch 3, loss 0.000027
# epoch 3, loss 0.000026
# epoch 3, loss 0.000023
# epoch 3, loss 0.000021
# epoch 3, loss 0.000021
# epoch 3, loss 0.000019
# epoch 3, loss 0.000017
# epoch 3, loss 0.000017
# epoch 3, loss 0.000016
# epoch 3, loss 0.000015
# epoch 3, loss 0.000014
# epoch 3, loss 0.000013
# epoch 3, loss 0.000013
# epoch 3, loss 0.000012
# epoch 3, loss 0.000012
# epoch 3, loss 0.000011
# epoch 3, loss 0.000010
# epoch 3, loss 0.000010
# epoch 3, loss 0.000009
# epoch 3, loss 0.000009
# epoch 3, loss 0.000008
# epoch 3, loss 0.000008
# epoch 3, loss 0.000007
# epoch 3, loss 0.000007
# epoch 3, loss 0.000006
# epoch 3, loss 0.000006
# epoch 3, loss 0.000006
# epoch 3, loss 0.000005
# epoch 3, loss 0.000005
# epoch 3, loss 0.000005
# epoch 3, loss 0.000005
# epoch 3, loss 0.000004
# epoch 3, loss 0.000004
# epoch 3, loss 0.000004
# epoch 3, loss 0.000003
# epoch 3, loss 0.000003
# epoch 3, loss 0.000003
# epoch 3, loss 0.000003
# epoch 3, loss 0.000003
# epoch 3, loss 0.000003
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000002
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000001
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000
# epoch 3, loss 0.000000

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 0.0002, -0.0003], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0004], grad_fn=<RsubBackward1>)
